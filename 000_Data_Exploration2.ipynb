# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_json('./data/train.json')

# %%
from datetime import date

# %%
from workalendar.usa import NewYork

# %%
cal = NewYork()

# %%
holidays = cal.holidays(2016)

# %%
holidays
# Out:
# [(datetime.date(2016, 1, 1), 'New year'),
#  (datetime.date(2016, 1, 18), 'Martin Luther King, Jr. Day'),
#  (datetime.date(2016, 2, 12), "Lincoln's Birthday"),
#  (datetime.date(2016, 2, 15), "Washington's Birthday"),
#  (datetime.date(2016, 5, 30), 'Memorial Day'),
#  (datetime.date(2016, 7, 4), 'Independence Day'),
#  (datetime.date(2016, 9, 5), 'Labor Day'),
#  (datetime.date(2016, 10, 10), 'Colombus Day'),
#  (datetime.date(2016, 11, 11), 'Veterans Day'),
#  (datetime.date(2016, 11, 24), 'Thanksgiving Day'),
#  (datetime.date(2016, 12, 25), 'Christmas Day'),
#  (datetime.date(2016, 12, 26), 'Christmas Day (Observed)')]

# %%
train[pd.to_datetime(train['created']).dt.date.map(cal.is_holiday)]
# Out:
#        bathrooms  bedrooms                       building_id  \
# 43224        1.0         1  26b7ab18fb7c34b2aa6c77a4e5c5a327
# 43409        1.0         2  046f3a231658321a14a75e7769f4e3a6
# 43519        1.0         1  6fdd8f3587e4baf2bb08052c608a9289
# 43608        2.0         4  027b750368bdc927a4884f997ed1776f
# 43649        1.0         0  46b5fd6e1ed6d002f5e6557f7e25bce1
# 43927        1.0         2  39be6a109f77f42e46646beefbbb1388
# 44011        1.0         0                                 0
# 44540        3.0         4  16d64a9b409dbfda65ac8f3dab34b718
# 44707        1.0         2  415814c4b23b8b868a304ac844f37a75
# 44806        1.0         1  7f85c7dbc97860c513a790a2df9dd451
# 44810        1.0         2  dbfcb61057d1ae6516d5c9066bb854f3
# 44885        1.0         1  f5685818501f50e5f18dc123dea6445f
# 45072        1.0         2  3b9ab6f2812ad5fd23af1eb6cb082f58
# 45441        1.0         2                                 0
# ...

# %%
train[pd.to_datetime(train['created']).dt.date == '2016-04-07']
# Out:
# Empty DataFrame
# Columns: [bathrooms, bedrooms, building_id, created, description, display_address, features, interest_level, latitude, listing_id, longitude, manager_id, photos, price, street_address]
# Index: []

# %%
train
# Out:
#         bathrooms  bedrooms                       building_id  \
# 10            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 10000         1.0         2  c5c8a357cba207596b04d1afd1e4f130
# 100004        1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa
# 100007        1.0         1  28d9ad350afeaab8027513a3e52ac8d5
# 100013        1.0         4                                 0
# 100014        2.0         4  38a913e46c94a7f46ddf19b756a9640c
# 100016        1.0         2  3ba49a93260ca5df92fde024cb4ca61f
# 100020        2.0         1  0372927bcb6a0949613ef5bf893bbac7
# 100026        1.0         1  a7efbeb58190aa267b4a9121cd0c88c0
# 100027        2.0         4                                 0
# 100030        1.0         0                                 0
# 10004         1.0         1                                 0
# 100044        1.0         2  67c9b420da4a365bc26a6cd0ef4a5320
# 100048        2.0         2                                 0
# ...

# %%
import datetime

# %%
school_holidays = ["2016-01-01",
                   "2016-01-18",
                   "2016-02-08",
                   "2016-02-15","2016-02-16","2016-02-17","2016-02-18","2016-02-19",
                   "2016-03-25",
                   "2016-04-25","2016-04-26","2016-04-27","2016-04-28","2016-04-29",
                   "2016-05-30",
                   "2016-06-09",
                  "2016-09-12",
                  "2016-10-03","2016-10-04",
                  "2016-10-10",
                  "2016-10-12",
                  "2016-11-08",
                  "2016-11-11",
                  "2016-11-24","2016-11-25",
                  "2016-12-26","2016-12-27","2016-12-28","2016-12-29","2016-12-30"
                  ]

# %%
start_summer = datetime.date(2016,6, 29)
end_summer = datetime.date(2016,9, 7)
summer = [start_summer +
          datetime.timedelta(days=x)
          for x in range((end_summer-start_summer).days + 1)]

# %%
[d.strftime("%Y-%m-%d") for d in summer]
# Out:
# ['2016-06-29',
#  '2016-06-30',
#  '2016-07-01',
#  '2016-07-02',
#  '2016-07-03',
#  '2016-07-04',
#  '2016-07-05',
#  '2016-07-06',
#  '2016-07-07',
#  '2016-07-08',
#  '2016-07-09',
#  '2016-07-10',
#  '2016-07-11',
#  '2016-07-12',
#  '2016-07-13',
#  '2016-07-14',
#  '2016-07-15',
#  '2016-07-16',
#  '2016-07-17',
#  '2016-07-18',
#  '2016-07-19',
#  '2016-07-20',
#  '2016-07-21',
#  '2016-07-22',
#  '2016-07-23',
#  '2016-07-24',
#  '2016-07-25',
#  '2016-07-26',
#  '2016-07-27',
#  '2016-07-28',
#  '2016-07-29',
#  '2016-07-30',
#  '2016-07-31',
#  '2016-08-01',
#  '2016-08-02',
#  '2016-08-03',
#  '2016-08-04',
#  '2016-08-05',
#  '2016-08-06',
#  '2016-08-07',
#  '2016-08-08',
#  '2016-08-09',
#  '2016-08-10',
#  '2016-08-11',
#  '2016-08-12',
#  '2016-08-13',
#  '2016-08-14',
#  '2016-08-15',
#  '2016-08-16',
#  '2016-08-17',
#  '2016-08-18',
#  '2016-08-19',
#  '2016-08-20',
#  '2016-08-21',
#  '2016-08-22',
#  '2016-08-23',
#  '2016-08-24',
#  '2016-08-25',
# ...

# %%
t = school_holidays
t.extend([d.strftime("%Y-%m-%d") for d in summer])

# %%
t
# Out:
# ['2016-01-01',
#  '2016-01-18',
#  '2016-02-08',
#  '2016-02-15',
#  '2016-02-16',
#  '2016-02-17',
#  '2016-02-18',
#  '2016-02-19',
#  '2016-03-25',
#  '2016-04-25',
#  '2016-04-26',
#  '2016-04-27',
#  '2016-04-28',
#  '2016-04-29',
#  '2016-05-30',
#  '2016-06-09',
#  '2016-09-12',
#  '2016-10-03',
#  '2016-10-04',
#  '2016-10-10',
#  '2016-10-12',
#  '2016-11-08',
#  '2016-11-11',
#  '2016-11-24',
#  '2016-11-25',
#  '2016-12-26',
#  '2016-12-27',
#  '2016-12-28',
#  '2016-12-29',
#  '2016-12-30',
#  '2016-06-29',
#  '2016-06-30',
#  '2016-07-01',
#  '2016-07-02',
#  '2016-07-03',
#  '2016-07-04',
#  '2016-07-05',
#  '2016-07-06',
#  '2016-07-07',
#  '2016-07-08',
#  '2016-07-09',
#  '2016-07-10',
#  '2016-07-11',
#  '2016-07-12',
#  '2016-07-13',
#  '2016-07-14',
#  '2016-07-15',
#  '2016-07-16',
#  '2016-07-17',
#  '2016-07-18',
#  '2016-07-19',
#  '2016-07-20',
#  '2016-07-21',
#  '2016-07-22',
#  '2016-07-23',
#  '2016-07-24',
#  '2016-07-25',
#  '2016-07-26',
# ...

# %%
train[pd.to_datetime(train['created']).dt.strftime('%Y-%m-%d').isin(t)]
# Out:
#         bathrooms  bedrooms                       building_id  \
# 100013        1.0         4                                 0
# 100016        1.0         2  3ba49a93260ca5df92fde024cb4ca61f
# 100071        3.5         4  45b4143a9841eb63d7203c4f21a64ff7
# 100075        1.0         1  d68497ff1f5ac77f143e5f21817ed6fb
# 100081        2.0         2  f115a9bff3a9c4e6eedc9114374b3d74
# 10010         1.0         0  d0234abbc01a982d54e8d446acc03405
# 100112        1.0         0  7b48df0cc3a04a24b062efbc5cf5022e
# 100115        1.0         1  1bd24d2906d981ec60703de71921dd2e
# 100117        1.0         0  379a891accd668964c9d2080cce45179
# 100138        1.0         0  ca9c594aba4534beae6ce71def209994
# 100139        1.0         3  6e9276972669ddcb097e71691f4c8f1b
# 100170        1.0         2  dd7b281c0dbafc8b53575ab78cca75d4
# 100193        1.0         1  91ca846d4a661b964fd0342af808e602
# 100215        2.0         3  e72c3fe47a374e028764154bee5b5925
# ...

# %%
pd.to_datetime(train['created']).dt.strftime('%y-%m-%d')
# Out:
# 10        16-06-24
# 10000     16-06-12
# 100004    16-04-17
# 100007    16-04-18
# 100013    16-04-28
# 100014    16-04-19
# 100016    16-04-27
# 100020    16-04-13
# 100026    16-04-20
# 100027    16-04-02
# 100030    16-04-14
# 10004     16-06-03
# 100044    16-04-19
# 100048    16-04-09
# 10005     16-06-01
# 100051    16-04-18
# 100052    16-04-22
# 100053    16-04-19
# 100055    16-04-20
# 100058    16-04-09
# 100062    16-04-12
# 100063    16-04-07
# 100065    16-04-13
# 100066    16-04-17
# 10007     16-06-07
# 100071    16-04-27
# 100075    16-04-25
# 100076    16-04-22
# 100079    16-04-21
# 100081    16-04-26
#             ...
# 99915     16-04-25
# 99917     16-04-26
# 99919     16-04-08
# 99921     16-04-29
# 99923     16-04-05
# 99924     16-04-24
# 99931     16-04-25
# 99933     16-04-03
# 99935     16-04-19
# 99937     16-04-14
# 9994      16-06-06
# 99953     16-04-26
# 99956     16-04-16
# 99960     16-04-05
# 99961     16-04-22
# 99964     16-04-29
# ...

# %%
train = pd.read_json('./data/train.json')

# %%
test = pd.read_json('./data/test.json')

# %%
train_test = pd.concat((train, test), axis=0).reset_index(drop=True)

# %%
managers_count = train_test['manager_id'].value_counts()

# %%
managers_count
# Out:
# e6472c7237327dd3903b3d6f6a94515a    6387
# 6e5c10246156ae5bdcd9b487ca99d96a    1683
# 8f5a9c893f6d602f4953fcc0b8e6e9b4    1011
# cb87dadbca78fad02b388dc9e8f25a5b     971
# 62b685cc0d876c3a1a51d63a0d6a8082     956
# 9df32cb8dda19d3222d66e69e258616b     862
# 2aa9bfa5f67ed9997ea341dee8a3a271     853
# b7de4cb395920136663132057fa89d84     849
# ad3d8ddc52c7e0859b5c6c7f7949c3bd     732
# c9c33695ee2a2f818e9f1d8f7d1c4b39     731
# 1fb46c4a72bcf764ac35fc23f394760d     719
# 5599e962719af3ccc2976855c2d5893c     713
# d2bce61e0e0079ebdc8c281e415e045b     677
# aa9e353a6b43b125cbc89cb751090a9e     643
# 62826f3ae01f2ddc93b9cd28c659ab2b     585
# dbbb6b990661b1e507a387f019bcb1a0     552
# b209e2c4384a64cc307c26759ee0c651     538
# 612a00076aefe8c98d1df4835640c74b     523
# 8262449f40e9117f7a9ea49b4a333993     522
# d1737922fe92ccb0dc37ba85589e6415     521
# fc81b75568d3655a922523cb0d77ea5b     505
# 8b53ccf4338806ab1be3dd0267711649     482
# 1067e078446a7897d2da493d2f741316     470
# ...

# %%
train_test['top_10_manager'] = train_test['manager_id'].apply(lambda x: 1 if x in managers_count.index.values[
    managers_count.values >= np.percentile(managers_count.values, 90)] else 0)

# %%
np.percentile(managers_count.values, 90)
# Out:
# 65.0

# %%
train_test['manager_id'].where(train_test.manager_id.values >= np.percentile(train_test.manager_id.value_counts(), 90))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-9ea2aecdb642> in <module>()
# ----> 1 train_test['manager_id'].where(train_test.manager_id.values >= np.percentile(train_test.manager_id.value_counts(), 90))
#
# TypeError: '>=' not supported between instances of 'str' and 'float'

# %%
np.percentile(train_test.manager_id.value_counts(), 90)
# Out:
# 65.0

# %%
train_test.manager_id.value_counts()
# Out:
# e6472c7237327dd3903b3d6f6a94515a    6387
# 6e5c10246156ae5bdcd9b487ca99d96a    1683
# 8f5a9c893f6d602f4953fcc0b8e6e9b4    1011
# cb87dadbca78fad02b388dc9e8f25a5b     971
# 62b685cc0d876c3a1a51d63a0d6a8082     956
# 9df32cb8dda19d3222d66e69e258616b     862
# 2aa9bfa5f67ed9997ea341dee8a3a271     853
# b7de4cb395920136663132057fa89d84     849
# ad3d8ddc52c7e0859b5c6c7f7949c3bd     732
# c9c33695ee2a2f818e9f1d8f7d1c4b39     731
# 1fb46c4a72bcf764ac35fc23f394760d     719
# 5599e962719af3ccc2976855c2d5893c     713
# d2bce61e0e0079ebdc8c281e415e045b     677
# aa9e353a6b43b125cbc89cb751090a9e     643
# 62826f3ae01f2ddc93b9cd28c659ab2b     585
# dbbb6b990661b1e507a387f019bcb1a0     552
# b209e2c4384a64cc307c26759ee0c651     538
# 612a00076aefe8c98d1df4835640c74b     523
# 8262449f40e9117f7a9ea49b4a333993     522
# d1737922fe92ccb0dc37ba85589e6415     521
# fc81b75568d3655a922523cb0d77ea5b     505
# 8b53ccf4338806ab1be3dd0267711649     482
# 1067e078446a7897d2da493d2f741316     470
# ...

# %%
managers_count.index.values[
    managers_count.values >= np.percentile(managers_count.values, 90)]
# Out:
# array(['e6472c7237327dd3903b3d6f6a94515a',
#        '6e5c10246156ae5bdcd9b487ca99d96a',
#        '8f5a9c893f6d602f4953fcc0b8e6e9b4',
#        'cb87dadbca78fad02b388dc9e8f25a5b',
#        '62b685cc0d876c3a1a51d63a0d6a8082',
#        '9df32cb8dda19d3222d66e69e258616b',
#        '2aa9bfa5f67ed9997ea341dee8a3a271',
#        'b7de4cb395920136663132057fa89d84',
#        'ad3d8ddc52c7e0859b5c6c7f7949c3bd',
#        'c9c33695ee2a2f818e9f1d8f7d1c4b39',
#        '1fb46c4a72bcf764ac35fc23f394760d',
#        '5599e962719af3ccc2976855c2d5893c',
#        'd2bce61e0e0079ebdc8c281e415e045b',
#        'aa9e353a6b43b125cbc89cb751090a9e',
#        '62826f3ae01f2ddc93b9cd28c659ab2b',
#        'dbbb6b990661b1e507a387f019bcb1a0',
#        'b209e2c4384a64cc307c26759ee0c651',
#        '612a00076aefe8c98d1df4835640c74b',
#        '8262449f40e9117f7a9ea49b4a333993',
#        'd1737922fe92ccb0dc37ba85589e6415',
#        'fc81b75568d3655a922523cb0d77ea5b',
#        '8b53ccf4338806ab1be3dd0267711649',
# ...

# %%
def _check_percentile(series_valcount,percentile):
        return series_valcount.index.values[
    series_valcount.values >= np.percentile(series_valcount.values, 100 - percentile)]

# %%
dict_percmag = {'top' + str(p) + 'manager': train_test['manager_id'].isin(_check_percentile(managers_count,90)) for p in [1,10,30]}

# %%
train_test.assign(**dict_percmag)
# Out:
#         bathrooms  bedrooms                       building_id  \
# 0             1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 1             1.0         2  c5c8a357cba207596b04d1afd1e4f130
# 2             1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa
# 3             1.0         1  28d9ad350afeaab8027513a3e52ac8d5
# 4             1.0         4                                 0
# 5             2.0         4  38a913e46c94a7f46ddf19b756a9640c
# 6             1.0         2  3ba49a93260ca5df92fde024cb4ca61f
# 7             2.0         1  0372927bcb6a0949613ef5bf893bbac7
# 8             1.0         1  a7efbeb58190aa267b4a9121cd0c88c0
# 9             2.0         4                                 0
# 10            1.0         0                                 0
# 11            1.0         1                                 0
# 12            1.0         2  67c9b420da4a365bc26a6cd0ef4a5320
# 13            2.0         2                                 0
# ...

# %%
train_test['manager_id'].isin(_check_percentile(mnagers_count,90)
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
# 5          True
# 6         False
# 7          True
# 8          True
# 9         False
# 10        False
# 11        False
# 12         True
# 13        False
# 14         True
# 15         True
# 16        False
# 17        False
# 18         True
# 19         True
# 20         True
# 21         True
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29         True
#           ...
# 123981     True
# 123982     True
# 123983    False
# 123984    False
# 123985     True
# 123986    False
# 123987     True
# 123988    False
# 123989    False
# 123990    False
# 123991     True
# 123992     True
# 123993    False
# 123994    False
# 123995     True
# 123996     True
# 123997    False
# 123998     True
# 123999    False
# 124000     True
# 124001     True
# 124002     True
# 124003     True
# 124004    False
# ...

# %%
train_test['manager_id'].apply(lambda x: 1 if x in managers_count.index.values[
    managers_count.values >= np.percentile(managers_count.values, 90)] else 0)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         0
# 5         1
# 6         0
# 7         1
# 8         1
# 9         0
# 10        0
# 11        0
# 12        1
# 13        0
# 14        1
# 15        1
# 16        0
# 17        0
# 18        1
# 19        1
# 20        1
# 21        1
# 22        1
# 23        1
# 24        1
# 25        1
# 26        1
# 27        1
# 28        1
# 29        1
#          ..
# 123981    1
# 123982    1
# 123983    0
# 123984    0
# 123985    1
# 123986    0
# 123987    1
# 123988    0
# 123989    0
# 123990    0
# 123991    1
# 123992    1
# 123993    0
# 123994    0
# 123995    1
# 123996    1
# 123997    0
# 123998    1
# 123999    0
# 124000    1
# 124001    1
# 124002    1
# 124003    1
# 124004    0
# 124005    0
# 124006    1
# 124007    1
# 124008    1
# 124009    1
# 124010    0
# Name: manager_id, dtype: int64

# %%
 pd.concat((train['manager_id'], test['manager_id']), axis=0)
# Out:
# 10        5ba989232d0489da1b5f2c45f6688adc
# 10000     7533621a882f71e25173b27e3139d83d
# 100004    d9039c43983f6e564b1482b273bd7b01
# 100007    1067e078446a7897d2da493d2f741316
# 100013    98e13ad4b495b9613cef886d79a6291f
# 100014    b209e2c4384a64cc307c26759ee0c651
# 100016    01287194f20de51872e81f660def4784
# 100020    e6472c7237327dd3903b3d6f6a94515a
# 100026    c1a6598437b7db560cde66e5a297a53f
# 100027    23a01ea7717b38875f5b070282d1b9d2
# 100030    e32475a6134d6d18279946b7b20a0f12
# 10004     2dee0868ac01057760055b856e66e942
# 100044    537e06890f6a86dbb70c187db5be4d55
# 100048    3813434aabfbad659a45f86a740cd23f
# 10005     75f38d077366d7964c2f3bb80c3e7b1d
# 100051    dbbb6b990661b1e507a387f019bcb1a0
# 100052    0411b25b134141100d8214ed6ec02f56
# 100053    ab15d581a04ed87b6f25d5aff8ddde30
# 100055    8f5a9c893f6d602f4953fcc0b8e6e9b4
# 100058    8f5a9c893f6d602f4953fcc0b8e6e9b4
# 100062    3793e58c60343a3fd6846ca2d2ef3c7f
# 100063    e6472c7237327dd3903b3d6f6a94515a
# ...

# %%
pd.concat((train['manager_id'], test['manager_id']), axis=0).value_counts()
# Out:
# e6472c7237327dd3903b3d6f6a94515a    6387
# 6e5c10246156ae5bdcd9b487ca99d96a    1683
# 8f5a9c893f6d602f4953fcc0b8e6e9b4    1011
# cb87dadbca78fad02b388dc9e8f25a5b     971
# 62b685cc0d876c3a1a51d63a0d6a8082     956
# 9df32cb8dda19d3222d66e69e258616b     862
# 2aa9bfa5f67ed9997ea341dee8a3a271     853
# b7de4cb395920136663132057fa89d84     849
# ad3d8ddc52c7e0859b5c6c7f7949c3bd     732
# c9c33695ee2a2f818e9f1d8f7d1c4b39     731
# 1fb46c4a72bcf764ac35fc23f394760d     719
# 5599e962719af3ccc2976855c2d5893c     713
# d2bce61e0e0079ebdc8c281e415e045b     677
# aa9e353a6b43b125cbc89cb751090a9e     643
# 62826f3ae01f2ddc93b9cd28c659ab2b     585
# dbbb6b990661b1e507a387f019bcb1a0     552
# b209e2c4384a64cc307c26759ee0c651     538
# 612a00076aefe8c98d1df4835640c74b     523
# 8262449f40e9117f7a9ea49b4a333993     522
# d1737922fe92ccb0dc37ba85589e6415     521
# fc81b75568d3655a922523cb0d77ea5b     505
# 8b53ccf4338806ab1be3dd0267711649     482
# 1067e078446a7897d2da493d2f741316     470
# ...
